# %%
"""
データセットのタイトル、説明、データの日付日時から、候補となる期間を出力して評価
"""
# Out:
# '\nデータセットのタイトル、説明、データの日付日時から、候補となる期間を出力して評価\n'

# %%
import pandas as pd
from extract_temporal import extract_temporal_from_textAndData

# %%
from IPython.display import display
def evaluation(index, dataset_title,dataset_notes,resource_title, resource_notes, filepath, column_name):
    print("==========================================")
    print("index: ",index)
    print("[input information]")
    print("- dataset title: ",dataset_title)
    print("- dataset notes: ",dataset_notes)
    print("- resource title: ", resource_title)
    print("- resource notes: ", resource_notes)
    print("- filepath: ",filepath)
    print("- column name: ",column_name)
    print("\n")

    print("[Estimation Result]")

    text = str(dataset_title) +" " + str(dataset_notes) + " "+ str(resource_title) + " " + str(resource_notes)
    temp_start,temp_end = extract_temporal_from_textAndData(text=text,filepath=filepath,column_name=column_name)
    print("- temporal_start: ", temp_start)
    print("- temporal_end: ", temp_end)
    print("\n")

# %%
df_test = pd.read_csv('evaluation/evaluation_input.csv', header=0)
#df_test = df_test.tail(2)
print("[評価で用いる入力データ一覧]")
display(df_test)
print("\n")
# Out:
# [評価で用いる入力データ一覧]
#          site                         dataset_title  \
# 0         埼玉県                 092045_栃木県_佐野市_イベント一覧
# 1         G空間                        高砂市ベストスポット2018
# 2         東京都                             東京都イベント一覧
# 3         東京都                                イベント一覧
# 4         東京都                      住宅着工統計（平成30年11月）
# 5         東京都     国勢調査による人口と世帯（年齢別）【2010年度（平成22年度）】
# 6     DATAGOV                         Measure Dates
# 7     DATAGOV                         Measure Dates
# 8     DATAGOV  Austin Code COVID-19 Complaint Cases
# 9   DATAGOVUK          Coronavirus Service Requests
# 10        東京都                 東京都_新型コロナウイルス陽性患者発表詳細
#
#                                         dataset_notes    resource_title  \
# 0                      イベント一覧のデータです。栃木県佐野市のオープンデータです。            イベント一覧
# 1   2018年に高砂市役所が発表した、市民投票によるベストスポットの位置情報です。 推奨データセ...               NaN
# 2   【東京都総務局】東京都が主催者等であるイベント情報の一覧です。 内閣官房情報通信技術（IT）...               NaN
# 3                                     文京区のイベント情報一覧です。            イベント一覧
# 4   【東京都住宅政策本部】　建築基準法第15条第１項の規定により、建築主からの届出を基に基幹統計...  平成30年11月新設住宅着工戸数
# 5      【中野区】中野区の2010年度(平成22年度)国勢調査による人口と世帯（年齢別）の一覧です。               NaN
# 6   Data Collection Periods for all measures on Ho...               NaN
# 7   Data Collection Periods for all measures on Ho...               NaN
# 8   This dataset displays info on COVID-19 complai...               NaN
# 9   A data set which shows the service requests th...               NaN
# 10  東京都 新型コロナウイルス対策サイト https://stopcovid19.metro.t...               NaN
#
#                                        resource_notes  \
# 0                             平成29年度のイベント一覧データのCSVです。
# 1                                                 NaN
# 2                                                 NaN
# 3                                     文京区のイベント情報一覧です。
# 4   【東京都住宅政策本部】　建築基準法第15条第１項の規定により、建築主からの届出を基に基幹統計...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                              filepath         column_name  \
# 0   https://www.geospatial.jp/ckan/dataset/609dd2a...                 NaN
# 1   https://www.geospatial.jp/ckan/dataset/2dc3b2b...                 NaN
# 2   http://www.opendata.metro.tokyo.jp/suisyoudata...                 開始日
# 3   https://www.city.bunkyo.lg.jp/library/opendata...                 開始日
# 4   http://www.metro.tokyo.jp/tosei/hodohappyo/pre...                 NaN
# 5   https://www.city.tokyo-nakano.lg.jp/dept/21250...                 NaN
# 6   https://data.medicare.gov/api/views/4j6d-yzce/...  Measure Start Date
# 7   https://data.medicare.gov/api/views/4j6d-yzce/...    Measure End Date
# 8   https://data.austintexas.gov/api/views/4p54-95...            OPENDATE
# 9   https://datamillnorth.org/download/coronavirus...                Date
# 10  https://stopcovid19.metro.tokyo.lg.jp/data/130...              公表_年月日
#
#                                           dataset_url                  memo
# 0                                                 NaN              テキストからのみ
# 1                                                 NaN              テキストからのみ
# 2                                                 NaN            テキストとデータから
# 3                                                 NaN               データからのみ
# 4   https://catalog.data.metro.tokyo.lg.jp/dataset...                テキストのみ
# 5                                                 NaN              テキストとデータ
# 6      https://catalog.data.gov/dataset/measure-dates        データ(米国表記)に期間あり
# 7      https://catalog.data.gov/dataset/measure-dates        データ(米国表記)に期間あり
# 8   https://catalog.data.gov/dataset/austin-code-c...  データあり（但し日付だけでなく時刻あり）
# 9   https://data.gov.uk/dataset/7ac20f2c-b0cc-4c4d...            データに日付時刻あり
# 10  https://catalog.data.metro.tokyo.lg.jp/dataset...                 データあり

# %%
for index, row in df_test.iterrows():
    evaluation(index=index,dataset_title=row.dataset_title,dataset_notes=row.dataset_notes,resource_title=row.resource_title, resource_notes=row.resource_notes,filepath=row.filepath,column_name=row.column_name)
# Out:
# ==========================================
# index:  0
# [input information]
# - dataset title:  092045_栃木県_佐野市_イベント一覧
# - dataset notes:  イベント一覧のデータです。栃木県佐野市のオープンデータです。
# - resource title:  イベント一覧
# - resource notes:  平成29年度のイベント一覧データのCSVです。
# - filepath:  https://www.geospatial.jp/ckan/dataset/609dd2ae-90fd-49c6-8125-aff213a99e9c/resource/333574d2-4698-4f4d-8a59-c51a46c5cbcc/download/109.csv
# - column name:  nan
#
#
# [Estimation Result]
# Error: 指定したcolumn_nameの列が見つかりません
# Error: zero length array
# - temporal_start:  2017-04-01 00:00:00
# - temporal_end:  2018-03-31 00:00:00
#
#
# ==========================================
# index:  1
# [input information]
# - dataset title:  高砂市ベストスポット2018
# - dataset notes:  2018年に高砂市役所が発表した、市民投票によるベストスポットの位置情報です。 推奨データセット及びNGSIに準じたオープンデータです。
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://www.geospatial.jp/ckan/dataset/2dc3b2b5-a856-4845-8f59-c18b07dd08b2/resource/8e74fffc-e02f-4d01-bcf7-ee32fe00806b/download/takasagocitybestspot2018.csv
# - column name:  nan
#
#
# [Estimation Result]
# Error: 指定したcolumn_nameの列が見つかりません
# Error: zero length array
# - temporal_start:  2018-01-01 00:00:00
# - temporal_end:  2018-12-31 00:00:00
#
#
# ==========================================
# index:  2
# [input information]
# - dataset title:  東京都イベント一覧
# - dataset notes:  【東京都総務局】東京都が主催者等であるイベント情報の一覧です。 内閣官房情報通信技術（IT）総合戦略室が平成29年12月22日に公開した、推奨データセットに準拠して作成しています。
# - resource title:  nan
# - resource notes:  nan
# - filepath:  http://www.opendata.metro.tokyo.jp/suisyoudataset/130001_event.csv
# - column name:  開始日
#
#
# [Estimation Result]
# - temporal_start:  2018-12-02 00:00:00
# - temporal_end:  2019-05-03 00:00:00
#
#
# ==========================================
# index:  3
# [input information]
# - dataset title:  イベント一覧
# - dataset notes:  文京区のイベント情報一覧です。
# - resource title:  イベント一覧
# - resource notes:  文京区のイベント情報一覧です。
# - filepath:  https://www.city.bunkyo.lg.jp/library/opendata-bunkyo/10sonota/01event/131059_event.csv
# - column name:  開始日
#
#
# [Estimation Result]
# - temporal_start:  2018-11-25 00:00:00
# - temporal_end:  2018-12-15 00:00:00
#
#
# ==========================================
# index:  4
# [input information]
# - dataset title:  住宅着工統計（平成30年11月）
# - dataset notes:  【東京都住宅政策本部】　建築基準法第15条第１項の規定により、建築主からの届出を基に基幹統計として集計されたものの東京都部分について改めて取りまとめたもの。
# - resource title:  平成30年11月新設住宅着工戸数
# - resource notes:  【東京都住宅政策本部】　建築基準法第15条第１項の規定により、建築主からの届出を基に基幹統計として集計されたものの東京都部分について改めて取りまとめたもの。
# - filepath:  http://www.metro.tokyo.jp/tosei/hodohappyo/press/2019/01/09/documents/05_01.xls
# - column name:  nan
#
#
# [Estimation Result]
# Error: Error in read_csv
# Error: zero length array
# - temporal_start:  2018-11-01 00:00:00
# - temporal_end:  2018-11-30 00:00:00
#
#
# ==========================================
# index:  5
# [input information]
# - dataset title:  国勢調査による人口と世帯（年齢別）【2010年度（平成22年度）】
# - dataset notes:  【中野区】中野区の2010年度(平成22年度)国勢調査による人口と世帯（年齢別）の一覧です。
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://www.city.tokyo-nakano.lg.jp/dept/212500/d027582_d/fil/131148_kokusei_2010_nenre.csv
# - column name:  nan
#
#
# [Estimation Result]
# Error: 指定したcolumn_nameの列が見つかりません
# Error: zero length array
# - temporal_start:  2010-04-01 00:00:00
# - temporal_end:  2011-03-31 00:00:00
#
#
# ==========================================
# index:  6
# [input information]
# - dataset title:  Measure Dates
# - dataset notes:  Data Collection Periods for all measures on Hospital Compare.
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://data.medicare.gov/api/views/4j6d-yzce/rows.csv?accessType=DOWNLOAD
# - column name:  Measure Start Date
#
#
# [Estimation Result]
# - temporal_start:  2010-07-01 00:00:00
# - temporal_end:  2019-01-01 00:00:00
#
#
# ==========================================
# index:  7
# [input information]
# - dataset title:  Measure Dates
# - dataset notes:  Data Collection Periods for all measures on Hospital Compare.
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://data.medicare.gov/api/views/4j6d-yzce/rows.csv?accessType=DOWNLOAD
# - column name:  Measure End Date
#
#
# [Estimation Result]
# - temporal_start:  2013-06-30 00:00:00
# - temporal_end:  2019-09-30 00:00:00
#
#
# ==========================================
# index:  8
# [input information]
# - dataset title:  Austin Code COVID-19 Complaint Cases
# - dataset notes:  This dataset displays info on COVID-19 complaints which Austin Code has received since March 17th, 2020.
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://data.austintexas.gov/api/views/4p54-9544/rows.csv?accessType=DOWNLOAD
# - column name:  OPENDATE
#
#
# [Estimation Result]
# - temporal_start:  2020-03-19 00:00:00
# - temporal_end:  2020-08-23 00:00:00
#
#
# ==========================================
# index:  9
# [input information]
# - dataset title:  Coronavirus Service Requests
# - dataset notes:  A data set which shows the service requests that have been made by Leeds residents for assistance during the Covid-19 Pandemic.
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://datamillnorth.org/download/coronavirus-service-requests/dd0b350d-0b0e-40e2-8a2e-8b906cd9c8d8/SERVICE%2520REQUESTS%252013.07.csv
# - column name:  Date
#
#
# [Estimation Result]
# - temporal_start:  2020-04-23 00:00:00
# - temporal_end:  2020-08-20 00:00:00
#
#
# ==========================================
# index:  10
# [input information]
# - dataset title:  東京都_新型コロナウイルス陽性患者発表詳細
# - dataset notes:  東京都 新型コロナウイルス対策サイト https://stopcovid19.metro.tokyo.lg.jp/ で公開している都内 新型コロナウイルス陽性患者の詳細データです。（注）退院済フラグには、死亡退院含む
# - resource title:  nan
# - resource notes:  nan
# - filepath:  https://stopcovid19.metro.tokyo.lg.jp/data/130001_tokyo_covid19_patients.csv
# - column name:  公表_年月日
#
#
# [Estimation Result]
# - temporal_start:  2020-01-24 00:00:00
# - temporal_end:  2020-08-24 00:00:00
